# %%
import pandas as pd

# %%
a=pd.read_excel("prophet.xlsx")

# %%
a.columns
# Out:
# Index(['Id', 'dynamic_without_external', 'day_per_day_without_external',
#        'dynamic_with_weather', 'day_per_day_with_weather',
#        'dynamic_with_promotion', 'day_per_day_with_promotion'],
#       dtype='object')

# %%
a.drop("dynamic_with_promotion",inplace=True, axis=1)

# %%
a.drop("day_per_day_with_promotion",inplace=True, axis=1)

# %%
a.to_excel("prophet.xlsx")

# %%
b=pd.read_excel("prophet.xlsx")

# %%
b
# Out:
#        Id  dynamic_without_external  day_per_day_without_external  \
# 0     154                  8.004709                      7.546973
# 1     156                  9.423813                      8.878799
# 2     157                  6.580283                      7.153538
# 3     158                 13.021152                     11.651529
# 4     159                 24.103730                     24.893185
# 5     160                 12.035362                     12.280814
# 6     161                 12.376777                     11.680926
# 7     162                 18.790726                     18.133235
# 8     163                 27.885496                     21.661023
# 9     164                 10.113327                      9.394859
# 10    175                 53.898392                     50.352783
# 11    176                 28.486416                     25.839121
# 12    177                 31.416877                     41.797767
# ...
